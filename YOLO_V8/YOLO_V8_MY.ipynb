# %%
# !nvidia-smi
# Out:
# Thu Jul 13 15:48:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/GDToT/Dataset_2
# Out:
# /content/drive/MyDrive/GDToT/Dataset_2

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test	valid
# README.dataset.txt  runs		 train	yolov8s.pt

# %%
# %cd /content/drive/MyDrive/GDToT/Dataset_2
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=2000 imgsz=640 plots=True patience=2000
# Out:
# /content/drive/MyDrive/GDToT/Dataset_2
# /bin/bash: yolo: command not found

# %%
# !ls runs/detect/train/
# Out:
# args.yaml  weights

# %%
Image(filename='/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/train2/results.png', width=600)

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/train4/weights/best.pt data=data.yaml
# Out:
# 2023-07-13 15:51:50.750728: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-13 15:51:52.017009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 40.4MB/s]
# val: Scanning /content/drive/MyDrive/GDToT/Dataset_2/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% 38/38 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:12<00:00,  4.08s/it]
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/train2/weights/best.pt conf=0.25 source=test/images
# Out:
# 2023-07-13 15:52:37.095398: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-13 15:52:37.955499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/19 /content/drive/MyDrive/GDToT/Dataset_2/test/images/download-1-_jpg.rf.965846b79a571544add001e024a468da.jpg: 640x640 1 bike, 16.6ms
# image 2/19 /content/drive/MyDrive/GDToT/Dataset_2/test/images/download-14-_jpg.rf.2b1924d4226a8e230074e03ecbddbc95.jpg: 640x640 1 bike, 16.8ms
# ...

# %%
Image(filename='/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/val2/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/val2/val_batch0_pred.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/val2/val_batch1_pred.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/GDToT/Dataset_2/runs/detect/val2/val_batch2_pred.jpg', width=600)
